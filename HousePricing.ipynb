# %%
import pandas as pd

# %%
df_train = pd.read_csv('../HousePricing/train.csv',keep_default_na=False,
                        na_values={'LotFrontage':'NA','MasVnrType':['NaN','NA'],'MasVnrArea':['NA'],'Electrical':'NA'})
df_test = pd.read_csv('../HousePricing/test.csv',keep_default_na=False,
                        na_values={'LotFrontage':'NA','MasVnrType':['NaN','NA'],'MasVnrArea':['NA'],'Electrical':'NA'})
#check na values for testing data and then select the colms

# %%
# !dir '../../House Pricing/'
# Out:
# Invalid switch - "..".

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave    NA      Reg
# 1        2          20       RL         80.0     9600   Pave    NA      Reg
# 2        3          60       RL         68.0    11250   Pave    NA      IR1
# 3        4          70       RL         60.0     9550   Pave    NA      IR1
# 4        5          60       RL         84.0    14260   Pave    NA      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave    NA      Reg
# 1456  1457          20       RL         85.0    13175   Pave    NA      Reg
# 1457  1458          70       RL         66.0     9042   Pave    NA      Reg
# 1458  1459          20       RL         68.0     9717   Pave    NA      Reg
# 1459  1460          20       RL         75.0     9937   Pave    NA      Reg
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1459 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df_train.isna().sum()[df_train.isna().sum()>0]
# Out:
# LotFrontage    259
# MasVnrType       8
# MasVnrArea       8
# Electrical       1
# dtype: int64

# %%
df_train['MSZoning'].isna().sum()
# Out:
# 0

# %%
df_test.isna().sum()[df_train.isna().sum()>0]
# Out:
# LotFrontage    227
# MasVnrType      16
# MasVnrArea      15
# Electrical       0
# dtype: int64

# %%
df_train['LotFrontage'].fillna(df_train['LotFrontage'].median(), inplace=True)
df_test['LotFrontage'].fillna(df_train['LotFrontage'].median(), inplace=True)

df_train['MasVnrType'].fillna(df_train['MasVnrType'].mode()[0], inplace=True)
df_test['MasVnrType'].fillna(df_train['MasVnrType'].mode()[0], inplace=True)

df_train['MasVnrArea'].fillna(df_train['LotFrontage'].median(), inplace=True)
df_test['MasVnrArea'].fillna(df_train['LotFrontage'].median(), inplace=True)

df_train['Electrical'].fillna(df_train['Electrical'].mode()[0], inplace=True)
df_test['Electrical'].fillna(df_train['Electrical'].mode()[0], inplace=True)

# %%
df_train.isna().sum()[df_train.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df_test.isna().sum()[df_train.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df_train.columns.to_series().groupby(df_train.dtypes).groups
# Out:
# {int64: ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'], float64: ['LotFrontage', 'MasVnrArea'], object: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'Garag
# ...

# %%
df_test.columns.to_series().groupby(df_train.dtypes).groups
# Out:
# {int64: ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'], float64: ['LotFrontage', 'MasVnrArea'], object: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'Gar
# ...

# %%
obj_col_tr = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
           'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
           'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd','MasVnrType', 'ExterQual',
           'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
           'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
           'Functional', 'FireplaceQu','GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual',
           'GarageCond', 'PavedDrive', 'PoolQC', 'Fence','MiscFeature', 'SaleType', 'SaleCondition']

# %%
obj_col_tt = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
              'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
              'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
              'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
              'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
              'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual',
              'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
for i in obj_col_tr:
    ser=pd.get_dummies(df_train[i],prefix=i)
    df_train=pd.concat([df_train,ser],axis=1)
    df_train.drop(i, axis=1, inplace=True)

# %%
for i in obj_col_tr:
    ser=pd.get_dummies(df_test[i],prefix=i)
    df_test=pd.concat([df_test,ser],axis=1)
    df_test.drop(i, axis=1, inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 401 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(35), uint8(364)
# memory usage: 941.1 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 389 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(26), object(8), uint8(353)
# memory usage: 913.4+ KB

# %%
df_train.columns.difference(df_test.columns)
# Out:
# Index(['Condition2_RRAe', 'Condition2_RRAn', 'Condition2_RRNn',
#        'Electrical_Mix', 'Exterior1st_ImStucc', 'Exterior1st_Stone',
#        'Exterior2nd_Other', 'GarageQual_Ex', 'GarageYrBlt_1906',
#        'GarageYrBlt_1908', 'GarageYrBlt_1914', 'GarageYrBlt_1929',
#        'GarageYrBlt_1931', 'GarageYrBlt_1933', 'Heating_Floor', 'Heating_OthW',
#        'HouseStyle_2.5Fin', 'MiscFeature_TenC', 'PoolQC_Fa',
#        'RoofMatl_ClyTile', 'RoofMatl_Membran', 'RoofMatl_Metal',
#        'RoofMatl_Roll', 'SalePrice', 'Utilities_NoSeWa'],
#       dtype='object')

# %%
df_test.columns.difference(df_train.columns)
# Out:
# Index(['Exterior1st_NA', 'Exterior2nd_NA', 'Functional_NA', 'GarageYrBlt_1895',
#        'GarageYrBlt_1896', 'GarageYrBlt_1917', 'GarageYrBlt_1919',
#        'GarageYrBlt_1943', 'GarageYrBlt_2207', 'KitchenQual_NA', 'MSZoning_NA',
#        'SaleType_NA', 'Utilities_NA'],
#       dtype='object')

# %%
df_test=df_test.drop(['Exterior1st_NA', 'Exterior2nd_NA', 'Functional_NA', 'GarageYrBlt_1895',
       'GarageYrBlt_1896', 'GarageYrBlt_1917', 'GarageYrBlt_1919',
       'GarageYrBlt_1943', 'GarageYrBlt_2207', 'KitchenQual_NA', 'MSZoning_NA',
       'SaleType_NA', 'Utilities_NA'],axis=1)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 376 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(26), object(8), uint8(340)
# memory usage: 894.9+ KB

# %%
g=df_test.columns.to_series().groupby(df_train.dtypes).groups
{k.name: v for k, v in g.items()}
# Out:
# {'uint8': Index(['MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL',
#         'MSZoning_RM', 'Street_Grvl', 'Street_Pave', 'Alley_Grvl', 'Alley_NA',
#         'Alley_Pave',
#         ...
#         'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#         'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#         'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#         'SaleCondition_Partial'],
#        dtype='object', length=340),
#  'int64': Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#         'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#         'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#         'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#         'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#         'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
# ...

# %%
df_test['YearRemodAdd']#['TotalBsmtSF']BsmtFullBath,BsmtHalfBath,GarageCars,GarageArea,BsmtUnfSF,BsmtFinSF2,BsmtFinSF1
# Out:
# 0       1961
# 1       1958
# 2       1998
# 3       1998
# 4       1992
#         ...
# 1454    1970
# 1455    1970
# 1456    1996
# 1457    1992
# 1458    1994
# Name: YearRemodAdd, Length: 1459, dtype: int64

# %%
df_test=df_test.drop(['TotalBsmtSF','BsmtFullBath','BsmtHalfBath','GarageCars','GarageArea','BsmtUnfSF','BsmtFinSF2',
              'BsmtFinSF1'],axis=1)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 368 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(26), uint8(340)
# memory usage: 803.7 KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 401 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(35), uint8(364)
# memory usage: 941.1 KB

# %%
a=list(df_train.columns.difference(df_test.columns))

# %%
df_test[a]=0

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 401 entries, Id to Utilities_NoSeWa
# dtypes: float64(2), int64(59), uint8(340)
# memory usage: 1.2 MB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 401 entries, Id to SaleCondition_Partial
# dtypes: float64(2), int64(35), uint8(364)
# memory usage: 941.1 KB

# %%
df_train.columns.difference(df_test.columns)
# Out:
# Index([], dtype='object')

# %%
df_test.columns.difference(df_train.columns)
# Out:
# Index([], dtype='object')

# %%
X = df_train.drop('SalePrice', axis=1)
y = df_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC=RandomForestClassifier()

# %%
RFC.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RFC.score(X_train,y_train)
# Out:
# 1.0

# %%
RFC.score(X_test,y_test)
# Out:
# 0.01598173515981735

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MMS=MinMaxScaler()

# %%
MMS.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = MMS.transform(X_train)
X_test_scaled = MMS.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KNR=KNeighborsRegressor(n_neighbors=5, weights='distance')

# %%
KNR.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(weights='distance')

# %%
KNR.score(X_train_scaled,y_train)
# Out:
# 1.0

# %%
KNR.score(X_test_scaled,y_test)
# Out:
# 0.7364072711126392

# %%
from sklearn.svm import SVR

# %%
SVR_poly=SVR(kernel='poly')
SVR_rbf=SVR(kernel='rbf')
SVR_lin=SVR(kernel='linear')

# %%
SVR_poly.fit(X_train_scaled,y_train)
SVR_rbf.fit(X_train_scaled,y_train)
SVR_lin.fit(X_train_scaled,y_train)
# Out:
# SVR(kernel='linear')

# %%
print('SVR_poly',SVR_poly.score(X_test_scaled,y_test))
print('SVR_rbf',SVR_rbf.score(X_test_scaled,y_test))
print('SVR_lin',SVR_lin.score(X_test_scaled,y_test))
# Out:
# SVR_poly -0.07755601439955617
# SVR_rbf -0.0785030277020684
# SVR_lin -0.04173876703693735

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(X_train,y_train)
# Out:
# 0.9786326345825619

# %%
model.score(X_test,y_test)
# Out:
# 0.8358808874985499

# %%
from sklearn.model_selection import GridSearchCV

# %%
par = {'n_estimators':[25,50,75,100],
        'max_depth':[15,16,17,18,19],
        'min_samples_leaf':[4,5,6,7]}

# %%
GridGSCV = GridSearchCV(RandomForestRegressor(),par, cv=10)

# %%
GridGSCV.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [15, 16, 17, 18, 19],
#                          'min_samples_leaf': [4, 5, 6, 7],
#                          'n_estimators': [25, 50, 75, 100]})

# %%
GridGSCV.best_score_ , GridGSCV.best_estimator_
# Out:
# (0.8571754609371769,
#  RandomForestRegressor(max_depth=19, min_samples_leaf=4, n_estimators=75))

# %%
Rf = GridGSCV.best_estimator_

# %%
Rf.fit(X,y)
# Out:
# RandomForestRegressor(max_depth=19, min_samples_leaf=4, n_estimators=75)
